# %%
from google.colab import auth
from google.cloud import bigquery
import pandas as pd

auth.authenticate_user()
project_id = "my-first-project-412206"
client = bigquery.Client(project=project_id)

# %%
query = """
SELECT*
FROM `bigquery-public-data.austin_bikeshare.bikeshare_trips`
"""
query_job = client.query(query).to_dataframe()
query_job
# Out:
#           trip_id     subscriber_type bike_id bike_type  \
# 0        29512432            Local365   21528  electric
# 1        29651222             Local31   21829  electric
# 2        29565267             Local31   16288  electric
# 3        29740080            Local365   21561  electric
# 4        29551828     3-Day Weekender   19328  electric
# ...           ...                 ...     ...       ...
# 2130004  28674267            Explorer   21440  electric
# 2130005  28580181  Student Membership   19783  electric
# 2130006  28616354  Student Membership    014G   classic
# 2130007  28648528            Explorer   19194  electric
# 2130008  28613096  Student Membership   21810  electric
#
#                        start_time  start_station_id  \
# 0       2023-05-03 13:23:02+00:00              7187
# 1       2023-05-17 23:17:20+00:00              2823
# 2       2023-05-08 11:57:19+00:00              3794
# 3       2023-05-27 20:50:54+00:00              4055
# 4       2023-05-06 22:41:12+00:00              3794
# ...                           ...               ...
# 2130004 2022-12-28 18:08:00+00:00              7189
# 2130005 2022-12-04 11:02:14+00:00              7189
# 2130006 2022-12-10 07:38:22+00:00              7189
# 2130007 2022-12-17 12:41:26+00:00              7189
# 2130008 2022-12-09 14:32:50+00:00              7189
#
#                            start_station_name end_station_id  \
# 0                         South Congress/Mary           7187
# 1        East 5th/Broadway @ Capital Metro HQ           2823
# 2                                  4th/Sabine           3794
# 3                                11th/Salina            4055
# 4                                  4th/Sabine           3794
# ...                                       ...            ...
# 2130004                       28th/Rio Grande           7189
# 2130005                       28th/Rio Grande           7189
# 2130006                       28th/Rio Grande           7189
# 2130007                       28th/Rio Grande           7189
# 2130008                       28th/Rio Grande           7189
#
#                                          end_station_name  duration_minutes
# 0        12th/San Jacinto @ State Capitol Visitors Garage                10
# 1                                              4th/Sabine                24
# 2                                            2nd/Congress                 3
# 3                                            11th/Salina                 13
# 4                                          Plaza Saltillo                 8
# ...                                                   ...               ...
# 2130004                                   28th/Rio Grande                62
# 2130005                                   28th/Rio Grande                42
# 2130006                                   28th/Rio Grande               173
# 2130007                                   28th/Rio Grande                13
# 2130008                                   28th/Rio Grande                48
#
# [2130009 rows x 10 columns]

# %% [markdown]
# Create a query to answer the following questions:
#
# ●How many tables are in the austin_bikeshare dataset?
#
# ●How many columns in the bikeshare_stations table have STRING data?

# %%
query = """
SELECT COUNT(*) AS total_tables
FROM `bigquery-public-data.austin_bikeshare.INFORMATION_SCHEMA.TABLES`;
"""

query_job = client.query(query).to_dataframe()

query_job
# Out:
#    total_tables
# 0             2

# %% [markdown]
# There are 2 tables in austin bikeshare dataset

# %%
query2 = """
SELECT column_name, data_type
FROM `bigquery-public-data.austin_bikeshare.INFORMATION_SCHEMA.COLUMNS`
WHERE table_name = 'bikeshare_stations';
"""

query_job = client.query(query2).to_dataframe()

query_job
# Out:
#           column_name  data_type
# 0          station_id      INT64
# 1                name     STRING
# 2              status     STRING
# 3             address     STRING
# 4      alternate_name     STRING
# 5   city_asset_number      INT64
# 6       property_type     STRING
# 7     number_of_docks      INT64
# 8          power_type     STRING
# 9    footprint_length      INT64
# 10    footprint_width    FLOAT64
# 11              notes     STRING
# 12   council_district      INT64
# 13      modified_date  TIMESTAMP

# %% [markdown]
# There are 7 columns in the bikeshare_stations table that have STRING data

# %% [markdown]
# Create a query to filter data based on the following conditions:
#
# ●Retrieve all trips where the bike_id is not null and the duration is greater than 1000 minutes.
#
# ●Filter trips where the trip_id is "Walk Up" and the end_station_name  is "Stolen"

# %%
query3 = """
SELECT *
FROM `bigquery-public-data.austin_bikeshare.bikeshare_trips`
WHERE bike_id IS NOT NULL AND duration_minutes > 1000;
"""

query_job = client.query(query3).to_dataframe()

query_job
# Out:
#        trip_id       subscriber_type bike_id bike_type  \
# 0     29731917  24 Hour Walk Up Pass   21457  electric
# 1     29731920  24 Hour Walk Up Pass   21803  electric
# 2     29554935       Pay-as-you-ride   21454  electric
# 3     30391277               Local31   23277  electric
# 4     30163408  24 Hour Walk Up Pass    2887   classic
# ...        ...                   ...     ...       ...
# 3631  28634839    Student Membership   22449  electric
# 3632  26351741    Student Membership   21551  electric
# 3633  27496076    Student Membership   18909  electric
# 3634  27866791    Student Membership   19085  electric
# 3635  27357116    Student Membership   22196  electric
#
#                     start_time  start_station_id  \
# 0    2023-05-27 10:47:04+00:00              3791
# 1    2023-05-27 10:47:20+00:00              3791
# 2    2023-05-07 11:44:09+00:00              4048
# 3    2023-07-30 11:23:37+00:00              3794
# 4    2023-07-08 23:42:32+00:00              3794
# ...                        ...               ...
# 3631 2022-12-13 15:57:24+00:00              4938
# 3632 2022-04-08 15:39:41+00:00              7188
# 3633 2022-08-17 14:44:33+00:00              7188
# 3634 2022-09-17 12:56:13+00:00              7188
# 3635 2022-08-01 14:09:43+00:00              7189
#
#                   start_station_name end_station_id  \
# 0                Lake Austin/Enfield           3791
# 1                Lake Austin/Enfield           3791
# 2     South Congress @ Bouldin Creek           4048
# 3                         4th/Sabine           3794
# 4                         4th/Sabine           3794
# ...                              ...            ...
# 3631                 22.5/Rio Grande           7189
# 3632                      22nd/Pearl           7189
# 3633                      22nd/Pearl           7189
# 3634                      22nd/Pearl           7189
# 3635                        28th/Rio           7189
#
#                                        end_station_name  duration_minutes
# 0                                   Lake Austin/Enfield              1407
# 1                                   Lake Austin/Enfield              1407
# 2                        South Congress @ Bouldin Creek              1231
# 3                                            23rd/Pearl              1281
# 4     Electric Drive/Sandra Muraida Way @ Pfluger Pe...              4263
# ...                                                 ...               ...
# 3631                                    28th/Rio Grande              1071
# 3632                                           28th/Rio              1158
# 3633                                           28th/Rio              1084
# 3634                                           28th/Rio              1198
# 3635                                           28th/Rio              1138
#
# [3636 rows x 10 columns]

# %%
query4 = """
SELECT *
FROM `bigquery-public-data.austin_bikeshare.bikeshare_trips`
WHERE trip_id = 'Walk Up' AND end_station_name = 'Stolen';
"""
query_job = client.query(query4).to_dataframe()

query_job
# Out:
# Empty DataFrame
# Columns: [trip_id, subscriber_type, bike_id, bike_type, start_time, start_station_id, start_station_name, end_station_id, end_station_name, duration_minutes]
# Index: []
